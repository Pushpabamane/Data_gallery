# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('CardioGoodFitness-1.csv')
data
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
data.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
data.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
data.head(20)
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0    TM195   18    Male         14        Single      3        4   29562
# 1    TM195   19    Male         15        Single      2        3   31836
# 2    TM195   19  Female         14     Partnered      4        3   30699
# 3    TM195   19    Male         12        Single      3        3   32973
# 4    TM195   20    Male         13     Partnered      4        2   35247
# 5    TM195   20  Female         14     Partnered      3        3   32973
# 6    TM195   21  Female         14     Partnered      3        3   35247
# 7    TM195   21    Male         13        Single      3        3   32973
# 8    TM195   21    Male         15        Single      5        4   35247
# 9    TM195   21  Female         15     Partnered      2        3   37521
# 10   TM195   22    Male         14        Single      3        3   36384
# 11   TM195   22  Female         14     Partnered      3        2   35247
# ...

# %%
data.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
data.describe(include='all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
data.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Education'}>],
#        [<Axes: title={'center': 'Usage'}>,
#         <Axes: title={'center': 'Fitness'}>],
#        [<Axes: title={'center': 'Income'}>,
#         <Axes: title={'center': 'Miles'}>]], dtype=object)

# %%
 #Relationship between categorical and continuous variable
sns.boxplot(x="Product", y="Income", data = data)
# Age distribution of gym goers with respect to gender
# Out:
# <Axes: xlabel='Product', ylabel='Income'>

# %%
# Relationship between categorical and continuous variable
#sns.boxplot(x="Product", y="Age", data = data) MaritalStatus
# Product distribution of gym goers with respect to gender

# %%
sns.boxplot(x="MaritalStatus", y="Age", data = data)
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='Age'>

# %%
# Set the figure size before creating the plot
plt.figure(figsize=(12, 8))  # Width: 12 inches, Height: 8 inches
sns.boxplot(x="MaritalStatus", y="Age", data=data)
plt.title('Age Distribution by Marital Status')
plt.show()

# %%
#Relationship between two categorical variables
pd.crosstab(data['Product'],data['Gender'])
# Out:
# Gender   Female  Male
# Product
# TM195        40    40
# TM498        29    31
# TM798         7    33

# %%
# Calculate the counts of each gender
gender_counts = data['Gender'].value_counts()
gender_counts
# Out:
# Gender
# Male      104
# Female     76
# Name: count, dtype: int64

# %%
# Plotting the pie chart
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Proportion of Gym Goers by Gender')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Calculate the counts of each gender
gender_counts = data['Gender'].value_counts()
# Plotting the donut chart
plt.figure(figsize=(8, 8))  # Adjust the figure size as needed
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140, wedgeprops=dict(width=0.3))
plt.title('Proportion of Gym Goers by Gender')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
# Display the plot
plt.show()

# %%
product_counts = data['Product'].value_counts()
plt.figure(figsize=(8, 6))
plt.bar(product_counts.index, product_counts.values, color=['blue', 'green', 'orange'])
plt.xlabel('Product')
plt.ylabel('Count')
plt.title('Number of Participants by Product')
plt.show()

# %%
#Relationship between two categorical variables
sns.countplot(x="Gender", hue = "Product", data = data)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
crosstab = pd.crosstab(data['Product'], data['Gender'])
crosstab.plot(kind='bar', stacked=True, figsize=(8, 6), color=['pink', 'blue'])
plt.xlabel('Product')
plt.ylabel('Count')
plt.title('Relationship between Product and Gender')
plt.legend(title='Gender')
plt.show()

# %%
pd.pivot_table(data, index=['Product', 'Gender'],
               columns = ['Gender'], 
               aggfunc=len)
# Out:
#                   Age       Education       Fitness       Income        \
# Gender         Female  Male    Female  Male  Female  Male Female  Male
# Product Gender
# TM195   Female   40.0   NaN      40.0   NaN    40.0   NaN   40.0   NaN
#         Male      NaN  40.0       NaN  40.0     NaN  40.0    NaN  40.0
# TM498   Female   29.0   NaN      29.0   NaN    29.0   NaN   29.0   NaN
#         Male      NaN  31.0       NaN  31.0     NaN  31.0    NaN  31.0
# TM798   Female    7.0   NaN       7.0   NaN     7.0   NaN    7.0   NaN
#         Male      NaN  33.0       NaN  33.0     NaN  33.0    NaN  33.0
#
#                MaritalStatus        Miles        Usage
# Gender                Female  Male Female  Male Female  Male
# Product Gender
# TM195   Female          40.0   NaN   40.0   NaN   40.0   NaN
#         Male             NaN  40.0    NaN  40.0    NaN  40.0
# TM498   Female          29.0   NaN   29.0   NaN   29.0   NaN
#         Male             NaN  31.0    NaN  31.0    NaN  31.0
# ...

# %%
data.max()
# Out:
# Product           TM798
# Age                  50
# Gender             Male
# Education            21
# MaritalStatus    Single
# Usage                 7
# Fitness               5
# Income           104581
# Miles               360
# dtype: object

# %%
sns.pairplot(data)
# Out:
# C:\Users\Pushpa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Pushpa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Pushpa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
data.hist(by='Gender', column = 'Income')
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
sns.distplot(data['Age'])
# Out:
# C:\Users\Pushpa\AppData\Local\Temp\ipykernel_15008\1298243121.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'])
# C:\Users\Pushpa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Density'>

# %%
data.hist(by='Gender', column = 'Product')
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
corr= data.corr()
sns.heatmap(corr, annot=True,cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 corr= data.corr()
#       2 sns.heatmap(corr, annot=True,cmap='coolwarm')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
#Average of miles for combination of given variables.
pd.pivot_table(data, 'Miles',index=['Product', 'Gender'], columns = ['MaritalStatus'])
# Out:
# MaritalStatus    Partnered      Single
# Product Gender
# TM195   Female   74.925926   78.846154
#         Male     80.190476   99.526316
# TM498   Female   94.000000   80.214286
#         Male     87.238095   91.100000
# TM798   Female  215.000000  133.333333
#         Male    176.315789  147.571429

# %%
#Relationship between two categorical variables
pd.crosstab(data['Product'], data['Gender'])

# %%
auto = pd.read_csv('Automobile (1).csv')

# %%
auto.head()

# %%
sns.distplot(auto['normalized_losses'])
plt.show()

# %%
sns.distplot(auto['normalized_losses'], kde=False, rug=True)
plt.show()

# %%
sns.jointplot(auto['engine_size'], auto['horsepower'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 sns.jointplot(auto['engine_size'], auto['horsepower'])
#       2 plt.show()
#
# NameError: name 'auto' is not defined

# %%
#kind : { "scatter" | "reg" | "resid" | "kde" | "hex" }
sns.jointplot(auto['engine_size'], auto['horsepower'], kind = 'hex')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 #kind : { "scatter" | "reg" | "resid" | "kde" | "hex" }
# ----> 2 sns.jointplot(auto['engine_size'], auto['horsepower'], kind = 'hex')
#       3 plt.show()
#
# NameError: name 'auto' is not defined

# %%
sns.pairplot(auto[['normalized_losses', 'engine_size', 'horsepower']])

# %%
sns.stripplot(auto['fuel_type'], auto['horsepower'], jitter = True)

# %%
sns.swarmplot(auto['fuel_type'], auto['horsepower'])

# %%
sns.boxplot(auto['number_of_doors'], auto['horsepower'], hue=auto['fuel_type'])

# %%
sns.barplot(auto['body_style'], auto['horsepower'], hue= auto['engine_location'])

# %%
sns.countplot(auto['body_style'], hue=auto['engine_location'])

# %%
sns.pointplot(auto['fuel_system'], auto['horsepower'], hue=auto['number_of_doors'])

# %%
sns.lmplot(x='horsepower', y ='peak_rpm', data= auto, hue='fuel_type')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 sns.lmplot(x='horsepower', y ='peak_rpm', data= auto, hue='fuel_type')
#
# NameError: name 'auto' is not defined
