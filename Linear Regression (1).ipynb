# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Advertising Budget and Sales.csv')
df
# Out:
#      Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  \
# 0             1             230.1                 37.8
# 1             2              44.5                 39.3
# 2             3              17.2                 45.9
# 3             4             151.5                 41.3
# 4             5             180.8                 10.8
# ..          ...               ...                  ...
# 195         196              38.2                  3.7
# 196         197              94.2                  4.9
# 197         198             177.0                  9.3
# 198         199             283.6                 42.0
# 199         200             232.1                  8.6
#
#      Newspaper Ad Budget ($)  Sales ($)
# 0                       69.2       22.1
# 1                       45.1       10.4
# 2                       69.3        9.3
# 3                       58.5       18.5
# 4                       58.4       12.9
# ..                       ...        ...
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)
df.head()
# Out:
#    TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  Sales ($)
# 0             230.1                 37.8                     69.2       22.1
# 1              44.5                 39.3                     45.1       10.4
# 2              17.2                 45.9                     69.3        9.3
# 3             151.5                 41.3                     58.5       18.5
# 4             180.8                 10.8                     58.4       12.9

# %%
df.tail()
# Out:
#      TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  Sales ($)
# 195              38.2                  3.7                     13.8        7.6
# 196              94.2                  4.9                      8.1        9.7
# 197             177.0                  9.3                      6.4       12.8
# 198             283.6                 42.0                     66.2       25.5
# 199             232.1                  8.6                      8.7       13.4

# %%
df.isnull().sum()
# Out:
# TV Ad Budget ($)           0
# Radio Ad Budget ($)        0
# Newspaper Ad Budget ($)    0
# Sales ($)                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   TV Ad Budget ($)         200 non-null    float64
#  1   Radio Ad Budget ($)      200 non-null    float64
#  2   Newspaper Ad Budget ($)  200 non-null    float64
#  3   Sales ($)                200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe()
# Out:
#        TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  \
# count        200.000000           200.000000               200.000000
# mean         147.042500            23.264000                30.554000
# std           85.854236            14.846809                21.778621
# min            0.700000             0.000000                 0.300000
# 25%           74.375000             9.975000                12.750000
# 50%          149.750000            22.900000                25.750000
# 75%          218.825000            36.525000                45.100000
# max          296.400000            49.600000               114.000000
#
#         Sales ($)
# count  200.000000
# mean    14.022500
# std      5.217457
# min      1.600000
# 25%     10.375000
# 50%     12.900000
# 75%     17.400000
# max     27.000000

# %%
# Correlation between independent and dependent variables. In this dataset,
#Advertisement budget spent on TV, 
#Radio and Newspaper media are the independent varaibles and 'Sales' is the dependent varaible.
df.corr()
# Out:
#                          TV Ad Budget ($)  Radio Ad Budget ($)  \
# TV Ad Budget ($)                 1.000000             0.054809
# Radio Ad Budget ($)              0.054809             1.000000
# Newspaper Ad Budget ($)          0.056648             0.354104
# Sales ($)                        0.782224             0.576223
#
#                          Newspaper Ad Budget ($)  Sales ($)
# TV Ad Budget ($)                        0.056648   0.782224
# Radio Ad Budget ($)                     0.354104   0.576223
# Newspaper Ad Budget ($)                 1.000000   0.228299
# Sales ($)                               0.228299   1.000000

# %% [markdown]
# # Data visulization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
fig = plt.figure(figsize = (7,4))
sns.lineplot(x='TV Ad Budget ($)',y='Sales ($)',data=df)
# Out:
# <AxesSubplot:xlabel='TV Ad Budget ($)', ylabel='Sales ($)'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
fig = plt.figure(figsize = (8,4))
sns.lineplot(x='Radio Ad Budget ($)',y='Sales ($)',data=df)
# Out:
# <AxesSubplot:xlabel='Radio Ad Budget ($)', ylabel='Sales ($)'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
fig = plt.figure(figsize = (8,4))
sns.lineplot(x='Newspaper Ad Budget ($)',y='Sales ($)',data=df)
# Out:
# <AxesSubplot:xlabel='Newspaper Ad Budget ($)', ylabel='Sales ($)'>

# %%
sns.pairplot(df)

# %%
# Heatmap to depict correlation coefficients
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#Scatterplot to depict relationship of TV Ad Budget on Sales
plt.scatter(df['TV Ad Budget ($)'],df['Sales ($)'])
plt.xlabel('TV Ad Budget ($K)')
plt.ylabel('Sales ($M)')
plt.title('Impact of TV Ad Budget on Sales')
plt.show()

# %%
#Scatterplot to depict relationship of Radio Ad Budget on Sales
plt.scatter(df['Radio Ad Budget ($)'],df['Sales ($)'])
plt.xlabel('Radio Ad Budget ($K)')
plt.ylabel('Sales ($M)')
plt.title('Impact of Radio Ad Budget on Sales')
plt.show()

# %%
#Scatterplot to depict relationship of Newspaper Ad Budget on Sales
plt.scatter(df['Newspaper Ad Budget ($)'],df['Sales ($)'])
plt.xlabel('Newspaper Ad Budget ($K)')
plt.ylabel('Sales ($M)')
plt.title('Impact of Newspaper Ad Budget on Sales')
plt.show()

# %%
#Scatter plot representing comparison of correlation coefficients
df.corr()['Sales ($)'][:3].plot(kind='bar')
plt.xlabel('Medium of Advertisement')
plt.ylabel('Sales Correlation Coeff')
plt.title('Impact of Medium of Ad on Sales')
# Out:
# Text(0.5, 1.0, 'Impact of Medium of Ad on Sales')

# %%
dfcor=df.corr()
dfcor
# Out:
#                          TV Ad Budget ($)  Radio Ad Budget ($)  \
# TV Ad Budget ($)                 1.000000             0.054809
# Radio Ad Budget ($)              0.054809             1.000000
# Newspaper Ad Budget ($)          0.056648             0.354104
# Sales ($)                        0.782224             0.576223
#
#                          Newspaper Ad Budget ($)  Sales ($)
# TV Ad Budget ($)                        0.056648   0.782224
# Radio Ad Budget ($)                     0.354104   0.576223
# Newspaper Ad Budget ($)                 1.000000   0.228299
# Sales ($)                               0.228299   1.000000

# %%
collist=df.columns.values
ncol=4
nrows=110
collist
# Out:
# array(['TV Ad Budget ($)', 'Radio Ad Budget ($)',
#        'Newspaper Ad Budget ($)', 'Sales ($)'], dtype=object)

# %%
len(collist)
# Out:
# 4

# %%
df[collist[0]]
# Out:
# 0      230.1
# 1       44.5
# 2       17.2
# 3      151.5
# 4      180.8
#        ...
# 195     38.2
# 196     94.2
# 197    177.0
# 198    283.6
# 199    232.1
# Name: TV Ad Budget ($), Length: 200, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the number of columns for the subplot
ncol = 3  # Example value
collist = df.columns.tolist()  # Assuming collist is a list of columns from your DataFrame

# Calculate the number of rows needed based on the length of collist and ncol
nrows = ((len(collist) + ncol - 1)*60) // ncol
print(nrows)
# Set the figure size
plt.figure(figsize=(ncol * 5, nrows * 5))

# Create subplots
for i in range(len(collist)):
    plt.subplot(nrows, ncol, i + 1)
    sns.boxplot(df[collist[i]], color='green', orient='v')
    plt.title(collist[i])  # Optional: Add title for each subplot
    plt.tight_layout()

plt.show()
# Out:
# 120

# %%
plt.subplot?
plt.figure(figsize=(ncol,1000*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
df.skew()

# %%
#treating using log
import numpy as np
for col in df.columns:
    if df.skew().loc[col]>0.55:
        df[col]=np.log1p(df[col])

# %%
df.skew()

# %%
x=df.drop(columns='Sales ($)')
y=df['Sales ($)']
print(x)
print(y)
# Out:
#      TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)
# 0               230.1                 37.8                 4.251348
# 1                44.5                 39.3                 3.830813
# 2                17.2                 45.9                 4.252772
# 3               151.5                 41.3                 4.085976
# 4               180.8                 10.8                 4.084294
# ..                ...                  ...                      ...
# 195              38.2                  3.7                 2.694627
# 196              94.2                  4.9                 2.208274
# 197             177.0                  9.3                 2.001480
# 198             283.6                 42.0                 4.207673
# 199             232.1                  8.6                 2.272126
#
# [200 rows x 3 columns]
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# ...

# %%
#Dimension and size of x
print(x.ndim)
print(x.size)
# Out:
# 2
# 600

# %%
#Dimension and size of x
print(y.ndim)
print(y.size)
# Out:
# 1
# 200

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=20)

# %%
x_train,x_test,y_train,y_test
# Out:
# (     TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)
#  12               23.8                 35.1                 4.203199
#  129              59.6                 12.0                 3.786460
#  51              100.4                  9.6                 1.526056
#  153             171.3                 39.7                 3.655840
#  88               88.3                 25.5                 4.309456
#  ..                ...                  ...                      ...
#  148              38.0                 40.3                 2.557227
#  137             273.7                 28.9                 4.105944
#  156              93.9                 43.5                 3.941582
#  15              195.4                 47.7                 3.987130
#  99              135.2                 41.7                 3.848018
#
#  [150 rows x 3 columns],
#       TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)
# ...

# %% [markdown]
# # Linear Regression Model¶

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [raw]
# Predictions and Model Evaluation using Test Data

# %%
y_pred_test=lr.predict(x_test)
y_pred_test
# Out:
# array([18.12682988, 19.25445963,  8.94444402, 15.72032223, 19.45457391,
#        17.173296  , 12.18022291,  8.28925155, 21.61556143,  5.65569545,
#        11.84719937, 13.95752491, 17.05726682, 11.27493202, 20.78164625,
#        24.65892347,  5.66292511, 13.24511282,  8.3034126 ,  4.85258346,
#        19.82573038, 16.29063913, 17.22976593, 23.22275757, 20.79664614,
#         8.94105197, 14.96242181, 11.11656468, 13.08151419, 15.32341056,
#         7.68201305, 19.62454848,  9.33529425, 10.77639241, 24.01273559,
#        15.22369007, 10.17604602,  9.10106792, 11.85896156, 13.78573039,
#        16.29741361, 12.08263437, 19.24781547, 18.03531343, 13.38072873,
#        18.37110202, 13.56221082, 13.44609764, 21.03199332, 10.88296559])

# %%
#compare y_pred_test with y_test(actual o/p)
from sklearn import metrics 
print("Mean Absolute Error: ",metrics.mean_absolute_error(y_test,y_pred_test))
print("Mean Squared Error: ",metrics.mean_squared_error(y_test,y_pred_test))
print("Root Mean Squared Error: ",metrics.mean_squared_error(y_test,y_pred_test,squared=False))
print("R2 Score: ",metrics.r2_score(y_test,y_pred_test))
# Out:
# Mean Absolute Error:  1.492507866975516
# Mean Squared Error:  4.866122453496422
# Root Mean Squared Error:  2.205928932104664
# R2 Score:  0.8604899445340665

# %%
#Scatter plot to depict Actual vs Predicted Values
plt.scatter(y_test,y_pred_test)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title('Actual vs Predicted Values using Test Data')
plt.show()

# %%
y_pred_train=lr.predict(x_train)

# %%
from sklearn import metrics 
print("Mean Absolute Error: ",metrics.mean_absolute_error(y_train,y_pred_train))
print("Mean Squared Error: ",metrics.mean_squared_error(y_train,y_pred_train))
print("Root Mean Squared Error: ",metrics.mean_squared_error(y_train,y_pred_train,squared=False))
print("R2 Score: ",metrics.r2_score(y_train,y_pred_train))
# Out:
# Mean Absolute Error:  1.1493315044596024
# Mean Squared Error:  2.1654409824102223
# Root Mean Squared Error:  1.47154374124938
# R2 Score:  0.9115455204858343

# %%
#Scatter plot to depict Actual vs Predicted Values
plt.scatter(y_train,y_pred_train)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title('Actual vs Predicted Values using Training Data')
plt.show()

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
#      TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  Sales ($)
# 0            0.969852             0.981522                 1.270548   1.552053
# 1            1.197376             1.082808                 0.784008   0.696046
# 2            1.516155             1.528463                 1.272195   0.907406
# 3            0.052050             1.217855                 1.079221   0.860330
# 4            0.394182             0.841614                 1.077274   0.215683
# ..                ...                  ...                      ...        ...
# 195          1.270941             1.321031                 0.530505   1.234053
# 196          0.617035             1.240003                 1.093193   0.830548
# 197          0.349810             0.942899                 1.332444   0.234898
# 198          1.594565             1.265121                 1.220018   2.205347
# 199          0.993206             0.990165                 1.019319   0.119610
#
# [200 rows x 4 columns]

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([33], dtype=int64), array([2], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#      TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  Sales ($)
# 0               230.1                 37.8                 4.251348       22.1
# 1                44.5                 39.3                 3.830813       10.4
# 2                17.2                 45.9                 4.252772        9.3
# 3               151.5                 41.3                 4.085976       18.5
# 4               180.8                 10.8                 4.084294       12.9
# ..                ...                  ...                      ...        ...
# 195              38.2                  3.7                 2.694627        7.6
# 196              94.2                  4.9                 2.208274        9.7
# 197             177.0                  9.3                 2.001480       12.8
# 198             283.6                 42.0                 4.207673       25.5
# 199             232.1                  8.6                 2.272126       13.4
#
# [199 rows x 4 columns]

# %%
x=df_new.drop(columns='Sales ($)')
y=df_new['Sales ($)']
print(x)
print(y)
# Out:
#      TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)
# 0               230.1                 37.8                 4.251348
# 1                44.5                 39.3                 3.830813
# 2                17.2                 45.9                 4.252772
# 3               151.5                 41.3                 4.085976
# 4               180.8                 10.8                 4.084294
# ..                ...                  ...                      ...
# 195              38.2                  3.7                 2.694627
# 196              94.2                  4.9                 2.208274
# 197             177.0                  9.3                 2.001480
# 198             283.6                 42.0                 4.207673
# 199             232.1                  8.6                 2.272126
#
# [199 rows x 3 columns]
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=20)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_test=lr.predict(x_test)
y_pred_test
# Out:
# array([18.7039163 , 19.58757633,  8.92998041, 16.39013022, 15.12614059,
#        10.70898674, 12.43441684,  8.2909136 , 16.56508875, 10.78823941,
#        21.12310669,  8.68917418, 17.17289744, 10.2544914 , 15.46279624,
#        24.88579036,  5.28479482, 13.64312753, 13.92781459,  4.61326837,
#        20.1259373 , 15.21706052, 10.16950332, 10.2616123 , 20.80247381,
#        12.10995572, 15.40494715,  6.75334558, 12.3906022 , 24.29522464,
#        17.32336883, 19.54561497, 15.32633389, 10.14242297, 24.3406786 ,
#        11.58847329,  5.4822107 , 21.77591714, 15.63846996, 16.54189962,
#        16.48462089, 19.09380392, 11.83114663,  5.90853606, 16.95262738,
#        18.78105525, 14.02655983, 15.05087047, 13.95390776, 15.99059935])

# %%
#compare y_pred_test with y_test(actual o/p)
from sklearn import metrics 
print("Mean Absolute Error: ",metrics.mean_absolute_error(y_test,y_pred_test))
print("Mean Squared Error: ",metrics.mean_squared_error(y_test,y_pred_test))
print("Root Mean Squared Error: ",metrics.mean_squared_error(y_test,y_pred_test,squared=False))
print("R2 Score: ",metrics.r2_score(y_test,y_pred_test))
# Out:
# Mean Absolute Error:  1.4770570680872495
# Mean Squared Error:  3.5856240673659214
# Root Mean Squared Error:  1.893574415587072
# R2 Score:  0.8738901426701065

# %%
#improve seen after re,oving outliers by considering z-scores of columns
R2 score increased fr0m 0.86 to 0.87
