# %%
class Iphone():
    #a is storage, b is colour, c is iphone13/14/15, d is 13/14/15, e is samsung/iphone
  def __init__(self,iphone,variant,colour,storage,v):
    self.ip=v
    self.variant=variant
    self.colour=colour
    self.storage=storage
    self.os='iOS 15'
    self.bat='3,500mAh battery'
    self.screen='Super Retina XDR display'
    self.ch='Lightning connector, Additionally, it supports wireless charging using Qi-compatible chargers'
  def output(self):
    print("\n\nPlease find below details according to the choice you made:")
    print("Model         :"+self.ip)
    print("OS            :"+self.os)
    print("RAM           :"+self.storage)
    print("Battery       :"+self.bat)
    print("colour        :"+self.colour)
    print("Charging type :"+self.ch)
    print("screen        :"+self.screen)
    if self.variant=='13':
      print("Camera        :"+'12MP Main Ultra Wide Telephoto')
      print("Price         :"+'starts from $799')
      print("Launch date   :"+'September 2021')
    elif self.variant=='14':
      print("Camera        :"+'12MP Main Ultra Wide Telephoto')
      print("Price         :"+'starts from $999')
      print("Launch date   :"+'September 2022')
    else:
      print("Camera        :"+'Advanced dual-camera system ,48MP Main Ultra Wide')
      print("Price         :"+'starts from $1099')
      print("Launch date   :"+'September 2023')


class Samsung():
    #a is storage, b is colour, c is iphone13/14/15, d is 13/14/15, e is samsung/iphone
  def __init__(self,iphone,variant,colour,storage,v):
    self.iphone=iphone      #a,s,z
    self.ip=v
    self.variant=variant
    self.colour=colour
    self.storage=storage
    self.os='Android'
    self.bat='Built-in rechargeable lithium‑ion battery'
    self.screen='AMOLED displays'
    self.ch='Type-C'
  def output(self):
    print("\n\nPlease find below details according to the choice you made:")
    print("Model         :"+self.ip)
    print("OS            :"+self.os)
    print("RAM           :"+self.storage)
    print("Battery       :"+self.bat)
    print("colour        :"+self.colour)
    print("Charging type :"+self.ch)
    print("screen        :"+self.screen)
    if self.variant=='a':
      print("Camera        :"+'wide-angle, ultra-wide-angle, telephoto, and depth sensors')
      print("Price         :"+'starts from $799')
      print("Launch date   :"+'February 2018')
    elif self.variant=='s':
      print("Camera        :"+'wide-angle, ultra-wide-angle, telephoto, and depth sensors')
      print("Price         :"+'starts from $999')
      print("Launch date   :"+'January 2022')
    else:
      print("Camera        :"+'wide-angle, ultra-wide-angle, telephoto, and depth sensors')
      print("Price         :"+'starts from $1099')
      print("Launch date   :"+'January 2023') 



#enter storage choices 
def storage():
  print("\nwhich storage do you prefer?")
  yn=input("Enter 1. 128\n      2. 256\n      3. 512: " ).capitalize()
  while yn not in ['1','2','3','128','256','512']:
    print("invalid input")
    yn=input("Enter 1. 128\n      2. 256\n      3. 512: " ).capitalize()
  if(yn=='1' or yn=='128'):
    yn='128'
    print(yn)
  elif(yn=='2' or yn=='256'):
    yn='256'
    print(yn)
  else:
    yn='512'
    print(yn)
  return yn          #return storage value

#enter colour choices 
def colour():
  print("\nwhich iphone colour do you prefer?")
  yn=input("Enter 1. Red\n      2. Black\n      3. Blue: " ).capitalize()
  while yn not in ['1','2','3','Red','Black','Blue']:
    print("invalid input")
    yn=input("Enter 1. Red\n      2. Black\n      3. Blue: " ).capitalize()
  if(yn=='1' or yn=='Red'):
    yn='Red'
    print('Red')
  elif(yn=='2' or yn=='Black'):
    yn='Black'
    print('Black')
  else:
    yn='Blue'
    print('Blue')
  a=storage()
  return a,yn           #return storage, colour


#enter iphone15 choices 15/15 +/15 pro
def iphone_variant(v):
  print("\nwhich iphone"+ v +" variant do you prefer?")
  yn=input("Enter 1. iphone "+ v +"\n      2. iphone"+ v +" pro\n      3. iphone "+ v +" pro max: " ).capitalize()
  while yn not in ['1','2','3','Iphone 15','Iphone 15 pro','Iphone 15 pro max']:
    print("invalid input")
    yn=input("Enter 1. iphone "+ v +"\n      2. iphone"+ v +" pro\n      3. iphone "+ v +" pro max: "  ).capitalize()
  if(yn=='1' or yn=='Iphone 15'):
    yn='Iphone '+v
    print('Iphone'+ v)
  elif(yn=='2' or yn=='Iphone 15 pro'):
    yn='Iphone '+v+' pro'
    print('Iphone ' +v+' pro')
  else:
    yn='Iphone '+v+' pro max'
    print('Iphone '+v+' pro max')
  a,b=colour()
  return a,b,yn                                  #return storage,colour,variant

#enter Iphone choice 13/14/15
def iphone_model():
  print("\nwhich iphone model you prefer?")
  yn=input("Enter 1. iphone 13\n      2. iphone 14\n      3. iphone 15: " ).capitalize()
  while yn not in ['1','2','3','Iphone 13','Iphone 14','Iphone 15']:
    print("invalid input")
    yn=input("Enter 1. iphone 13\n      2. iphone 14\n      3. iphone 15: " ).capitalize()
  if(yn=='1' or yn=='Iphone 13'):
    yn='13'
    print("Iphone 13")
    a,b,c=iphone_variant(yn)
    return a,b,c,yn
  elif(yn=='2' or yn=='Iphone 14'):
    yn='14'
    print("Iphone 14")
    a,b,c=iphone_variant(yn)
    return a,b,c,yn             # c is variant
  else:
    yn='15'
    print("Iphone 15")
    a,b,c=iphone_variant(yn)
    return a,b,c,yn

#enter samsung Galaxy Z variant
def samsung_zvariant(v):
  print("\nwhich samsung Galaxy Z variant do you prefer?")
  yn=input("Enter 1. samsung Galaxy Z Fold 3\n      2. samsung Galaxy Z Filp 3\n      3. samsung Galaxy Z Fold 2: " ).capitalize()
  while yn not in ['1','2','3','Samsung galaxy z fold 3','Samsung galaxy z filp 3','Samsung galaxy z fold 2']:
    print("invalid input")
    yn=input("Enter 1. samsung Galaxy Z Fold 3\n      2. samsung Galaxy Z Filp 3\n      3. samsung Galaxy Z Fold 2: "  ).capitalize()
  if(yn=='1' or yn=='Samsung galaxy z fold 3' ):
    yn='Samsung galaxy z fold 3'
    print('Samsung galaxy z fold 3')
  elif(yn=='2' or yn=='Samsung galaxy z filp 3'):
    yn='Samsung galaxy z filp 3'
    print('Samsung galaxy z filp 3')
  else:
    yn='Samsung galaxy z fold 2'
    print('Samsung galaxy z fold 2')
  a,b=colour()
  return a,b,yn 

#enter samsung Galaxy A variant
def samsung_avariant(v):
  print("\nwhich samsung Galaxy A variant do you prefer?")
  yn=input("Enter 1. samsung Galaxy A 52\n      2. samsung Galaxy A 32\n      3. samsung Galaxy A 12: " ).capitalize()
  while yn not in ['1','2','3','Samsung galaxy a 52','Samsung galaxy a 32','Samsung galaxy a 12']:
    print("invalid input")
    yn=input("Enter 1. samsung Galaxy A 52\n      2. samsung Galaxy A 32\n      3. samsung Galaxy A 12: "  ).capitalize()
  if(yn=='1' or yn=='Samsung galaxy a 52' ):
    yn='Samsung galaxy a 52'
    print('Samsung galaxy a 52')
  elif(yn=='2' or yn=='Samsung galaxy a 32'):
    yn='Samsung galaxy a 32'
    print('Samsung galaxy a 32')
  else:
    yn='Samsung galaxy a 12'
    print('Samsung galaxy a 12')
  a,b=colour()
  return a,b,yn   

#enter samsung Galaxy S variant
def samsung_svariant(v):
  print("\nwhich samsung Galaxy S variant do you prefer?")
  yn=input("Enter 1. samsung Galaxy S\n      2. samsung Galaxy S +\n      3. samsung Galaxy S ultra: " ).capitalize()
  while yn not in ['1','2','3','Samsung galaxy s','Samsung galaxy s +','Samsung galaxy s ultra']:
    print("invalid input")
    yn=input("Enter 1. samsung Galaxy S\n      2. samsung Galaxy S +\n      3. samsung Galaxy S ultra: "  ).capitalize()
  if(yn=='1' or yn=='Samsung galaxy s' ):
    yn='Samsung galaxy s'
    print('Samsung galaxy s')
  elif(yn=='2' or yn=='Samsung galaxy s +'):
    yn='Samsung galaxy s +'
    print('Samsung galaxy s +')
  else:
    yn='Samsung galaxy s ultra'
    print('Samsung galaxy s ultra')
  a,b=colour()
  return a,b,yn           #yn variant

#enter Samsung choice 13/14/15
def samsung_model():
  print("\nwhich Samsung model you prefer?")
  yn=input("Enter 1. Samsung Galaxy S Series\n      2. Samsung Galaxy A Series\n      3. Samsung Galaxy Z Series: " ).capitalize()
  while yn not in ['1','2','3','Samsung galaxy s series','Samsung galaxy a series','Samsung galaxy z series']:
    print("invalid input")
    yn=input("Enter 1. Samsung Galaxy S Series\n      2. Samsung Galaxy A Series\n      3. Samsung Galaxy Z Series: " ).capitalize()
  if(yn=='1' or yn=='Samsung galaxy s series'):
    yn='s'
    print("Samsung galaxy s series")
    a,b,c=samsung_svariant(yn)
    return a,b,c,yn
  elif(yn=='2' or yn=='Samsung galaxy a series'):
    yn='a'
    print("Samsung galaxy a series")
    a,b,c=samsung_avariant(yn)        
    return a,b,c,yn             #yn s/a/z , c variant
  else:
    yn='z'
    print("Samsung galaxy z series")
    a,b,c=samsung_zvariant(yn)
    return a,b,c,yn

#enter phone choice samsung or iphone
def samsung_iphone():
  yn=input("\nEnter 1. samsung \n      2. iphone: " ).capitalize()
  while yn not in ['1','2','Samsung','Iphone']:
    print("invalid input")
    yn=input("Enter 1. samsung\n      2. iphone: ").capitalize()
  if(yn=='1' or yn=='Samsung'):
    yn='Samsung'
    a,b,c,d=samsung_model()
    return a,b,c,d,yn           #d s,a,z
  else:
    yn='Iphone'
    a,b,c,d=iphone_model()
    return a,b,c,d,yn            #d is 13/14/15  c is variant

#enter phone choice yes/no
def yes_no():
  yn=input("Do you want a phone? \n Yes/No: ").capitalize()
  while yn not in ['Yes','No']:
    print("invalid input")
    yn=input("Do you want a phone? \n Yes/No: ").capitalize()
  if(yn=='Yes'):
    return 1
  else:
    return 0
yn=yes_no()
if yn==1: 
  #a is storage, b is colour, c is iphone13/14/15, d is 13/14/15 e is samsung/iphone
  #a is storage, b is colour, c is samsung s/a/z, d is variant e is samsung/iphone
  a,b,c,d,e=samsung_iphone()
  if e=='Iphone':
    d=Iphone(e,d,b,a,c)
    d.output()
  else:
    d=Samsung(e,d,b,a,c)
    d.output()
else:
  print ("HAPPY SHOPPING ON OTHER ITEMS")
# Out:
# Do you want a phone?
#  Yes/No:  yes
#
# Enter 1. samsung
#       2. iphone:  2
# which iphone model you prefer?
# Enter 1. iphone 13
#       2. iphone 14
#       3. iphone 15:  1
# Iphone 13
#
# which iphone13 variant do you prefer?
# Enter 1. iphone 13
#       2. iphone13 pro
#       3. iphone 13 pro max:  3
# Iphone 13 pro max
#
# which iphone colour do you prefer?
# Enter 1. Red
#       2. Black
#       3. Blue:  2
# Black
#
# which storage do you prefer?
# Enter 1. 128
#       2. 256
#       3. 512:  3
# 512
#
#
# Please find below details according to the choice you made:
# Model         :Iphone 13 pro max
# OS            :iOS 15
# RAM           :512
# Battery       :3,500mAh battery
# colour        :Black
# Charging type :Lightning connector, Additionally, it supports wireless charging using Qi-compatible chargers
# screen        :Super Retina XDR display
# Camera        :12MP Main Ultra Wide Telephoto
# Price         :starts from $799
# Launch date   :September 2021
